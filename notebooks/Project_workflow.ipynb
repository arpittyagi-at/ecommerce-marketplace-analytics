# %% [markdown]
# #  Olist E-Commerce Analytics — Project Workflow
#
# ```text
#                          RAW OLIST DATA
#                                 │
#                                 ▼
#                        1. UNDERSTAND DATA
#                                 │
#                                 ▼
#                        2. DATA QUALITY CHECK
#                                 │
#                                 ▼
#                           3. SQL DATABASE
#                                 │
#                                 ▼
#                        4. BUSINESS QUESTIONS
#                                 │
#                                 ▼
#                           SQL ANALYSIS
#                                 │
#                                 ▼
#                            PYTHON EDA
#                                 │
#                                 ▼
#                        FEATURE ENGINEERING
#                                 │
#                     ┌───────────┴───────────┐
#                     ▼                       ▼
#                POWER BI                    ML
#                DASHBOARD             Late Delivery
#                     │                       │
#                     └───────────┬───────────┘
#                                 ▼
#                         BUSINESS INSIGHTS
#                                 │
#                                 ▼
#                            FINAL REPORT
#                                 │
#                                 ▼
#                              GITHUB
